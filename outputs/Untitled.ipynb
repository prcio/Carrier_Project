# %%
import numpy as np
while np.load('arrays.npz') as data:
# Out:
# NpzFile 'arrays.npz' with keys: params, x_obj_true, x_car_true, u_obj_true, u_obj_noisy...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       2 b = np.load('arrays.npz')
#       3 print(b)
# ----> 4 print(b(params))
#
# NameError: name 'params' is not defined
